# %% [markdown]
# <a href="https://colab.research.google.com/github/davide-sonzini/Flight_price_map/blob/main/Flight_price_map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install amadeus pandas

import pandas as pd
import time
import datetime
from amadeus import Client, ResponseError
from google.colab import files
import random

# -------------------------------
# CONFIG
# -------------------------------
API_KEY = "ligX17GEhAERS34XjfmMW6rpG1c5uHZu"       # Replace with your Amadeus test GET API key
API_SECRET = "2jWVw0p9UA72Ykke" # Replace with your Amadeus secret
ORIGIN_AIRPORT = "MXP"
DEPARTURE_DATE = (datetime.date.today() + datetime.timedelta(days=30)).strftime("%Y-%m-%d")
AUTOSAVE_INTERVAL = 50  # Save after every 50 airports
SUBSET_SIZE = 1000       # Number of airports to randomly select

# -------------------------------
# INIT CLIENT
# -------------------------------
amadeus = Client(client_id=API_KEY, client_secret=API_SECRET)

# -------------------------------
# LOAD AND SUBSET AIRPORTS
# -------------------------------
airports = pd.read_csv('airports.csv')

if len(airports) > SUBSET_SIZE:
    airports_subset = airports.sample(n=SUBSET_SIZE, random_state=42).reset_index(drop=True)
else:
    airports_subset = airports.copy()

# Optional: save subset for reference
airports_subset.to_csv('airports_subset_1000.csv', index=False)

print(f"Random subset of {len(airports_subset)} airports created.")

# -------------------------------
# PRICE BUCKET / COLOR FUNCTION
# -------------------------------
def assign_bucket_and_color(price):
    if price is None:
        return "No Data", "#CCCCCC"
    elif price < 100:
        return "<100", "#0000FF"        # Blue
    elif price < 200:
        return "100-200", "#00FF00"    # Green 1
    elif price < 400:
        return "200-400", "#008000"    # Green 2
    elif price < 800:
        return "400-800", "#FFFF00"    # Yellow
    elif price < 1000:
        return "800-1000", "#FFA500"   # Orange
    else:
        return ">1000", "#FF0000"      # Red

# -------------------------------
# FUNCTION TO GET CHEAPEST FLIGHT
# -------------------------------
def get_cheapest_flight(origin, destination, date):
    try:
        response = amadeus.shopping.flight_offers_search.get(
            originLocationCode=origin,
            destinationLocationCode=destination,
            departureDate=date,
            adults=1,
            max=5
        )
        data = response.data
        if not data:
            return None
        prices = [float(offer['price']['total']) for offer in data if 'price' in offer]
        return min(prices) if prices else None
    except ResponseError as e:
        print(f"Error fetching {origin} -> {destination}: {e}")
        return None

# -------------------------------
# LOOP OVER DESTINATIONS
# -------------------------------
results = []
output_file = 'airports_with_prices.csv'

for i, dest in enumerate(airports_subset['IATA']):
    if dest == ORIGIN_AIRPORT:
        continue

    print(f"Fetching {ORIGIN_AIRPORT} -> {dest} ({i+1}/{len(airports_subset)}) ...")
    price = get_cheapest_flight(ORIGIN_AIRPORT, dest, DEPARTURE_DATE)
    bucket, color = assign_bucket_and_color(price)

    results.append({
        'origin': ORIGIN_AIRPORT,
        'destination': dest,
        'price_usd': price,
        'bucket': bucket,
        'color': color
    })

    # Autosave
    if (i+1) % AUTOSAVE_INTERVAL == 0:
        df = pd.DataFrame(results)
        df.to_csv(output_file, index=False)
        print(f"Autosaved {i+1} airports to {output_file}")

    time.sleep(1)  # Prevent hitting rate limits

# -------------------------------
# FINAL SAVE
# -------------------------------
df = pd.DataFrame(results)
df.to_csv(output_file, index=False)
files.download(output_file)
print(f"Done! CSV saved as {output_file}")
# Out:
# Requirement already satisfied: amadeus in /usr/local/lib/python3.12/dist-packages (12.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Random subset of 1000 airports created.
# Fetching MXP -> QVL (1/1000) ...
# Error fetching MXP -> QVL: [400]
#
# Fetching MXP -> BRT (2/1000) ...
# Fetching MXP -> ZIV (3/1000) ...
# Error fetching MXP -> ZIV: [400]
#
# Fetching MXP -> HPV (4/1000) ...
# Fetching MXP -> FOD (5/1000) ...
# Fetching MXP -> MAD (6/1000) ...
# Fetching MXP -> BVY (7/1000) ...
# Error fetching MXP -> BVY: [400]
#
# Fetching MXP -> KTD (8/1000) ...
# Error fetching MXP -> KTD: [400]
#
# Fetching MXP -> ELH (9/1000) ...
# Fetching MXP -> SXS (10/1000) ...
# Fetching MXP -> XNJ (11/1000) ...
# Fetching MXP -> BPF (12/1000) ...
# Error fetching MXP -> BPF: [400]
#
# Fetching MXP -> JJI (13/1000) ...
# Error fetching MXP -> JJI: [400]
#
# Fetching MXP -> TFS (14/1000) ...
# Fetching MXP -> DEA (15/1000) ...
# Error fetching MXP -> DEA: [400]
#
# Fetching MXP -> KGX (16/1000) ...
# Error fetching MXP -> KGX: [400]
#
# Fetching MXP -> IPN (17/1000) ...
# Error fetching MXP -> IPN: [400]
#
# Fetching MXP -> ILZ (18/1000) ...
# Error fetching MXP -> ILZ: [400]
#
# Fetching MXP -> VOG (19/1000) ...
# Fetching MXP -> HAC (20/1000) ...
# Error fetching MXP -> HAC: [400]
#
# Fetching MXP -> INY (21/1000) ...
# Fetching MXP -> VRK (22/1000) ...
# Error fetching MXP -> VRK: [400]
#
# Fetching MXP -> PUG (23/1000) ...
# Fetching MXP -> MEA (24/1000) ...
# Fetching MXP -> UTK (25/1000) ...
# Fetching MXP -> TEM (26/1000) ...
# Fetching MXP -> YPA (27/1000) ...
# Error fetching MXP -> YPA: [400]
#
# Fetching MXP -> TUS (28/1000) ...
# Fetching MXP -> DSC (29/1000) ...
# Fetching MXP -> PLX (30/1000) ...
# Fetching MXP -> ITH (31/1000) ...
# Fetching MXP -> MQQ (32/1000) ...
# Fetching MXP -> MYQ (33/1000) ...
# Fetching MXP -> TWU (34/1000) ...
# Fetching MXP -> JKH (35/1000) ...
# Error fetching MXP -> JKH: [400]
#
# Fetching MXP -> YND (36/1000) ...
# Error fetching MXP -> YND: [400]
#
# Fetching MXP -> KLF (37/1000) ...
# Fetching MXP -> YDF (38/1000) ...
# Fetching MXP -> CUU (39/1000) ...
# Error fetching MXP -> CUU: [400]
#
# Fetching MXP -> TUK (40/1000) ...
# Fetching MXP -> DJG (41/1000) ...
# Fetching MXP -> VFA (42/1000) ...
# Fetching MXP -> DIG (43/1000) ...
# Error fetching MXP -> DIG: [400]
#
# Fetching MXP -> DLD (44/1000) ...
# Error fetching MXP -> DLD: [400]
#
# Fetching MXP -> MEZ (45/1000) ...
# Error fetching MXP -> MEZ: [400]
#
# Fetching MXP -> BJO (46/1000) ...
# Error fetching MXP -> BJO: [400]
#
# Fetching MXP -> SHT (47/1000) ...
# Fetching MXP -> LPU (48/1000) ...
# Error fetching MXP -> LPU: [400]
#
# Fetching MXP -> SXO (49/1000) ...
# Error fetching MXP -> SXO: [400]
#
# Fetching MXP -> PWK (50/1000) ...
# Error fetching MXP -> PWK: [400]
#
# Autosaved 50 airports to airports_with_prices.csv
# Fetching MXP -> HOV (51/1000) ...
# Fetching MXP -> AZD (52/1000) ...
# Fetching MXP -> GAH (53/1000) ...
# Fetching MXP -> YLJ (54/1000) ...
# Fetching MXP -> YGR (55/1000) ...
# Error fetching MXP -> YGR: [400]
#
# Fetching MXP -> NUM (56/1000) ...
# Fetching MXP -> GME (57/1000) ...
# Error fetching MXP -> GME: [400]
#
# Fetching MXP -> TEE (58/1000) ...
# Fetching MXP -> LIQ (59/1000) ...
# Error fetching MXP -> LIQ: [400]
#
# Fetching MXP -> MUO (60/1000) ...
# Error fetching MXP -> MUO: [400]
#
# Fetching MXP -> PKX (61/1000) ...
# Fetching MXP -> MXY (62/1000) ...
# Error fetching MXP -> MXY: [400]
#
# Fetching MXP -> MNC (63/1000) ...
# Error fetching MXP -> MNC: [400]
#
# Fetching MXP -> ZGC (64/1000) ...
# Fetching MXP -> MUX (65/1000) ...
# Fetching MXP -> GZT (66/1000) ...
# Fetching MXP -> RUA (67/1000) ...
# Fetching MXP -> JQF (68/1000) ...
# Error fetching MXP -> JQF: [400]
#
# Fetching MXP -> APZ (69/1000) ...
# Error fetching MXP -> APZ: [400]
#
# Fetching MXP -> CLQ (70/1000) ...
# Error fetching MXP -> CLQ: [400]
#
# Fetching MXP -> YZG (71/1000) ...
# Fetching MXP -> PGV (72/1000) ...
# Error fetching MXP -> PGV: [400]
#
# Fetching MXP -> URJ (73/1000) ...
# Error fetching MXP -> URJ: [400]
#
# Fetching MXP -> IKS (74/1000) ...
# Error fetching MXP -> IKS: [400]
#
# Fetching MXP -> SJB (75/1000) ...
# Fetching MXP -> LAA (76/1000) ...
# Fetching MXP -> BSO (77/1000) ...
# Error fetching MXP -> BSO: [400]
#
# Fetching MXP -> YHI (78/1000) ...
# Fetching MXP -> KVA (79/1000) ...
# Fetching MXP -> ANN (80/1000) ...
# Fetching MXP -> ZAM (81/1000) ...
# Fetching MXP -> XNA (82/1000) ...
# Fetching MXP -> ZOS (83/1000) ...
# Error fetching MXP -> ZOS: [400]
#
# Fetching MXP -> AGX (84/1000) ...
# Fetching MXP -> ERM (85/1000) ...
# Error fetching MXP -> ERM: [400]
#
# Fetching MXP -> AKU (86/1000) ...
# Fetching MXP -> PNR (87/1000) ...
# Error fetching MXP -> PNR: [400]
#
# Fetching MXP -> RDR (88/1000) ...
# Fetching MXP -> RKP (89/1000) ...
# Error fetching MXP -> RKP: [400]
#
# Fetching MXP -> CMX (90/1000) ...
# Error fetching MXP -> CMX: [400]
#
# Fetching MXP -> BFQ (91/1000) ...
# Error fetching MXP -> BFQ: [400]
#
# Fetching MXP -> KMO (92/1000) ...
# Error fetching MXP -> KMO: [400]
#
# Fetching MXP -> USM (93/1000) ...
# Fetching MXP -> STR (94/1000) ...
# Fetching MXP -> PBV (95/1000) ...
# Error fetching MXP -> PBV: [400]
#
# Fetching MXP -> DPL (96/1000) ...
# Fetching MXP -> JNS (97/1000) ...
# Error fetching MXP -> JNS: [400]
#
# Fetching MXP -> NEG (98/1000) ...
# Fetching MXP -> LGK (99/1000) ...
# Fetching MXP -> MRY (100/1000) ...
# Autosaved 100 airports to airports_with_prices.csv
# Fetching MXP -> TNE (101/1000) ...
# Error fetching MXP -> TNE: [400]
#
# Fetching MXP -> YUM (102/1000) ...
# Fetching MXP -> SGU (103/1000) ...
# Fetching MXP -> YSL (104/1000) ...
# Error fetching MXP -> YSL: [400]
#
# Fetching MXP -> GON (105/1000) ...
# Fetching MXP -> CUZ (106/1000) ...
# Fetching MXP -> PET (107/1000) ...
# Fetching MXP -> FCS (108/1000) ...
# Fetching MXP -> GVL (109/1000) ...
# Fetching MXP -> MDZ (110/1000) ...
# Fetching MXP -> KUT (111/1000) ...
# Fetching MXP -> KRB (112/1000) ...
# Error fetching MXP -> KRB: [400]
#
# Fetching MXP -> LGB (113/1000) ...
# Fetching MXP -> ENS (114/1000) ...
# Error fetching MXP -> ENS: [400]
#
# Fetching MXP -> TPI (115/1000) ...
# Error fetching MXP -> TPI: [400]
#
# Fetching MXP -> MCI (116/1000) ...
# Fetching MXP -> BWT (117/1000) ...
# Error fetching MXP -> BWT: [400]
#
# Fetching MXP -> ORB (118/1000) ...
# Error fetching MXP -> ORB: [400]
#
# Fetching MXP -> TYF (119/1000) ...
# Fetching MXP -> CBV (120/1000) ...
# Error fetching MXP -> CBV: [400]
#
# Fetching MXP -> CAP (121/1000) ...
# Fetching MXP -> RJA (122/1000) ...
# Fetching MXP -> GBE (123/1000) ...
# Fetching MXP -> GER (124/1000) ...
# Fetching MXP -> LTM (125/1000) ...
# Error fetching MXP -> LTM: [400]
#
# Fetching MXP -> DOE (126/1000) ...
# Error fetching MXP -> DOE: [400]
#
# Fetching MXP -> LWC (127/1000) ...
# Error fetching MXP -> LWC: [400]
#
# Fetching MXP -> BTJ (128/1000) ...
# Error fetching MXP -> BTJ: [400]
#
# Fetching MXP -> MSJ (129/1000) ...
# Fetching MXP -> SJE (130/1000) ...
# Fetching MXP -> YDT (131/1000) ...
# Fetching MXP -> CUE (132/1000) ...
# Fetching MXP -> NOP (133/1000) ...
# Fetching MXP -> GAU (134/1000) ...
# Fetching MXP -> BTT (135/1000) ...
# Error fetching MXP -> BTT: [400]
#
# Fetching MXP -> AER (136/1000) ...
# Fetching MXP -> SRT (137/1000) ...
# Fetching MXP -> SXQ (138/1000) ...
# Error fetching MXP -> SXQ: [400]
#
# Fetching MXP -> YRG (139/1000) ...
# Fetching MXP -> SJD (140/1000) ...
# Fetching MXP -> LXC (141/1000) ...
# Fetching MXP -> XIY (142/1000) ...
# Fetching MXP -> TLV (143/1000) ...
# Fetching MXP -> WUD (144/1000) ...
# Fetching MXP -> XVV (145/1000) ...
# Fetching MXP -> BFD (146/1000) ...
# Fetching MXP -> NPL (147/1000) ...
# Fetching MXP -> TLH (148/1000) ...
# Fetching MXP -> AFZ (149/1000) ...
# Fetching MXP -> YPM (150/1000) ...
# Error fetching MXP -> YPM: [400]
#
# Autosaved 150 airports to airports_with_prices.csv
# Fetching MXP -> VLP (151/1000) ...
# Error fetching MXP -> VLP: [400]
#
# Fetching MXP -> ZIA (152/1000) ...
# Error fetching MXP -> ZIA: [400]
#
# Fetching MXP -> CEQ (153/1000) ...
# Error fetching MXP -> CEQ: [400]
#
# Fetching MXP -> YRF (154/1000) ...
# Error fetching MXP -> YRF: [400]
#
# Fetching MXP -> YGW (155/1000) ...
# Fetching MXP -> SNC (156/1000) ...
# Fetching MXP -> QGY (157/1000) ...
# Fetching MXP -> FNE (158/1000) ...
# Fetching MXP -> RPM (159/1000) ...
# Fetching MXP -> KTP (160/1000) ...
# Fetching MXP -> SSE (161/1000) ...
# Error fetching MXP -> SSE: [400]
#
# Fetching MXP -> BXK (162/1000) ...
# Error fetching MXP -> BXK: [400]
#
# Fetching MXP -> ZQF (163/1000) ...
# Fetching MXP -> IVA (164/1000) ...
# Error fetching MXP -> IVA: [400]
#
# Fetching MXP -> KWI (165/1000) ...
# Fetching MXP -> XIZ (166/1000) ...
# Fetching MXP -> HBG (167/1000) ...
# Error fetching MXP -> HBG: [400]
#
# Fetching MXP -> LAR (168/1000) ...
# Error fetching MXP -> LAR: [400]
#
# Fetching MXP -> GPO (169/1000) ...
# Error fetching MXP -> GPO: [400]
#
# Fetching MXP -> TRS (170/1000) ...
# Fetching MXP -> FEB (171/1000) ...
# Error fetching MXP -> FEB: [400]
#
# Fetching MXP -> BOA (172/1000) ...
# Fetching MXP -> TII (173/1000) ...
# Fetching MXP -> RNL (174/1000) ...
# Fetching MXP -> CFE (175/1000) ...
# Fetching MXP -> KSU (176/1000) ...
# Fetching MXP -> ESR (177/1000) ...
# Error fetching MXP -> ESR: [400]
#
# Fetching MXP -> OKY (178/1000) ...
# Fetching MXP -> SDR (179/1000) ...
# Fetching MXP -> GEO (180/1000) ...
# Fetching MXP -> LCC (181/1000) ...
# Fetching MXP -> KDL (182/1000) ...
# Fetching MXP -> YGV (183/1000) ...
# Fetching MXP -> TOX (184/1000) ...
# Error fetching MXP -> TOX: [400]
#
# Fetching MXP -> RMA (185/1000) ...
# Fetching MXP -> GRR (186/1000) ...
# Fetching MXP -> IWJ (187/1000) ...
# Error fetching MXP -> IWJ: [400]
#
# Fetching MXP -> YLC (188/1000) ...
# Error fetching MXP -> YLC: [400]
#
# Fetching MXP -> KVX (189/1000) ...
# Error fetching MXP -> KVX: [400]
#
# Fetching MXP -> RJK (190/1000) ...
# Fetching MXP -> DRG (191/1000) ...
# Error fetching MXP -> DRG: [400]
#
# Fetching MXP -> AVN (192/1000) ...
# Error fetching MXP -> AVN: [400]
#
# Fetching MXP -> YCR (193/1000) ...
# Fetching MXP -> VAO (194/1000) ...
# Fetching MXP -> KTN (195/1000) ...
# Fetching MXP -> SBR (196/1000) ...
# Fetching MXP -> LTO (197/1000) ...
# Error fetching MXP -> LTO: [400]
#
# Fetching MXP -> PSK (198/1000) ...
# Error fetching MXP -> PSK: [400]
#
# Fetching MXP -> HCC (199/1000) ...
# Error fetching MXP -> HCC: [400]
#
# Fetching MXP -> HMN (200/1000) ...
# Error fetching MXP -> HMN: [400]
#
# Autosaved 200 airports to airports_with_prices.csv
# Fetching MXP -> KND (201/1000) ...
# Error fetching MXP -> KND: [400]
#
# Fetching MXP -> ICN (202/1000) ...
# Fetching MXP -> AKA (203/1000) ...
# Fetching MXP -> LEU (204/1000) ...
# Fetching MXP -> YMY (205/1000) ...
# Fetching MXP -> BFB (206/1000) ...
# Fetching MXP -> SYO (207/1000) ...
# Fetching MXP -> TQR (208/1000) ...
# Error fetching MXP -> TQR: [400]
#
# Fetching MXP -> OGL (209/1000) ...
# Error fetching MXP -> OGL: [400]
#
# Fetching MXP -> JIU (210/1000) ...
# Fetching MXP -> BAV (211/1000) ...
# Fetching MXP -> INV (212/1000) ...
# Fetching MXP -> IGA (213/1000) ...
# Error fetching MXP -> IGA: [400]
#
# Fetching MXP -> HHH (214/1000) ...
# Fetching MXP -> BQE (215/1000) ...
# Error fetching MXP -> BQE: [400]
#
# Fetching MXP -> ZPH (216/1000) ...
# Error fetching MXP -> ZPH: [400]
#
# Fetching MXP -> 0 (217/1000) ...
# Error fetching MXP -> 0: [400]
#
# Fetching MXP -> ADB (218/1000) ...
# Fetching MXP -> UIP (219/1000) ...
# Fetching MXP -> SVP (220/1000) ...
# Error fetching MXP -> SVP: [400]
#
# Fetching MXP -> OMO (221/1000) ...
# Error fetching MXP -> OMO: [400]
#
# Fetching MXP -> EGA (222/1000) ...
# Error fetching MXP -> EGA: [400]
#
# Fetching MXP -> BJV (223/1000) ...
# Fetching MXP -> LEY (224/1000) ...
# Error fetching MXP -> LEY: [400]
#
# Fetching MXP -> UIH (225/1000) ...
# Fetching MXP -> TNC (226/1000) ...
# Fetching MXP -> QOW (227/1000) ...
# Fetching MXP -> NTX (228/1000) ...
# Fetching MXP -> ASD (229/1000) ...
# Error fetching MXP -> ASD: [400]
#
# Fetching MXP -> OSK (230/1000) ...
# Fetching MXP -> FBU (231/1000) ...
# Error fetching MXP -> FBU: [400]
#
# Fetching MXP -> YEK (232/1000) ...
# Fetching MXP -> USL (233/1000) ...
# Error fetching MXP -> USL: [400]
#
# Fetching MXP -> OBN (234/1000) ...
# Fetching MXP -> WKM (235/1000) ...
# Error fetching MXP -> WKM: [400]
#
# Fetching MXP -> EOI (236/1000) ...
# Fetching MXP -> YJN (237/1000) ...
# Fetching MXP -> XAI (238/1000) ...
# Error fetching MXP -> XAI: [400]
#
# Fetching MXP -> DAX (239/1000) ...
# Fetching MXP -> KJA (240/1000) ...
# Fetching MXP -> VPN (241/1000) ...
# Fetching MXP -> XES (242/1000) ...
# Fetching MXP -> AXT (243/1000) ...
# Fetching MXP -> KTR (244/1000) ...
# Error fetching MXP -> KTR: [400]
#
# Fetching MXP -> UPG (245/1000) ...
# Fetching MXP -> YNB (246/1000) ...
# Fetching MXP -> GBD (247/1000) ...
# Fetching MXP -> CCK (248/1000) ...
# Error fetching MXP -> CCK: [400]
#
# Fetching MXP -> SKY (249/1000) ...
# Error fetching MXP -> SKY: [400]
#
# Fetching MXP -> UVF (250/1000) ...
# Error fetching MXP -> UVF: [400]
#
# Autosaved 250 airports to airports_with_prices.csv
# Fetching MXP -> RVV (251/1000) ...
# Error fetching MXP -> RVV: [400]
#
# Fetching MXP -> GVR (252/1000) ...
# Error fetching MXP -> GVR: [400]
#
# Fetching MXP -> KLG (253/1000) ...
# Error fetching MXP -> KLG: [400]
#
# Fetching MXP -> OKT (254/1000) ...
# Error fetching MXP -> OKT: [400]
#
# Fetching MXP -> EMK (255/1000) ...
# Error fetching MXP -> EMK: [400]
#
# Fetching MXP -> GUL (256/1000) ...
# Error fetching MXP -> GUL: [400]
#
# Fetching MXP -> HUK (257/1000) ...
# Error fetching MXP -> HUK: [400]
#
# Fetching MXP -> YQQ (258/1000) ...
# Fetching MXP -> DBQ (259/1000) ...
# Error fetching MXP -> DBQ: [400]
#
# Fetching MXP -> TIZ (260/1000) ...
# Fetching MXP -> EGX (261/1000) ...
# Fetching MXP -> BRO (262/1000) ...
# Fetching MXP -> SFD (263/1000) ...
# Error fetching MXP -> SFD: [400]
#
# Fetching MXP -> TAB (264/1000) ...
# Fetching MXP -> JRG (265/1000) ...
# Fetching MXP -> NGB (266/1000) ...
# Fetching MXP -> VLD (267/1000) ...
# Error fetching MXP -> VLD: [400]
#
# Fetching MXP -> RRG (268/1000) ...
# Error fetching MXP -> RRG: [400]
#
# Fetching MXP -> SKV (269/1000) ...
# Error fetching MXP -> SKV: [400]
#
# Fetching MXP -> ZCL (270/1000) ...
# Error fetching MXP -> ZCL: [400]
#
# Fetching MXP -> HJJ (271/1000) ...
# Fetching MXP -> BBI (272/1000) ...
# Fetching MXP -> KHS (273/1000) ...
# Error fetching MXP -> KHS: [400]
#
# Fetching MXP -> RJN (274/1000) ...
# Error fetching MXP -> RJN: [400]
#
# Fetching MXP -> XMY (275/1000) ...
# Error fetching MXP -> XMY: [400]
#
# Fetching MXP -> WSY (276/1000) ...
# Fetching MXP -> YBO (277/1000) ...
# Error fetching MXP -> YBO: [400]
#
# Fetching MXP -> TGR (278/1000) ...
# Fetching MXP -> KPC (279/1000) ...
# Fetching MXP -> BME (280/1000) ...
# Fetching MXP -> GUM (281/1000) ...
# Fetching MXP -> BHK (282/1000) ...
# Fetching MXP -> YRR (283/1000) ...
# Fetching MXP -> PTK (284/1000) ...
# Fetching MXP -> HET (285/1000) ...
# Fetching MXP -> PFN (286/1000) ...
# Error fetching MXP -> PFN: [400]
#
# Fetching MXP -> CHT (287/1000) ...
# Fetching MXP -> PHE (288/1000) ...
# Fetching MXP -> GLS (289/1000) ...
# Fetching MXP -> HBA (290/1000) ...
# Fetching MXP -> BRR (291/1000) ...
# Fetching MXP -> MKQ (292/1000) ...
# Fetching MXP -> ROA (293/1000) ...
# Fetching MXP -> MYI (294/1000) ...
# Fetching MXP -> SIC (295/1000) ...
# Fetching MXP -> LBJ (296/1000) ...
# Fetching MXP -> USK (297/1000) ...
# Error fetching MXP -> USK: [400]
#
# Fetching MXP -> HUH (298/1000) ...
# Fetching MXP -> PED (299/1000) ...
# Error fetching MXP -> PED: [400]
#
# Fetching MXP -> MRK (300/1000) ...
# Error fetching MXP -> MRK: [400]
#
# Autosaved 300 airports to airports_with_prices.csv
# Fetching MXP -> AGZ (301/1000) ...
# Error fetching MXP -> AGZ: [400]
#
# Fetching MXP -> LSS (302/1000) ...
# Error fetching MXP -> LSS: [400]
#
# Fetching MXP -> GZA (303/1000) ...
# Error fetching MXP -> GZA: [400]
#
# Fetching MXP -> SIT (304/1000) ...
# Fetching MXP -> AGY (305/1000) ...
# Error fetching MXP -> AGY: [400]
#
# Fetching MXP -> 108 (306/1000) ...
# Error fetching MXP -> 108: [400]
#
# Fetching MXP -> HYL (307/1000) ...
# Error fetching MXP -> HYL: [400]
#
# Fetching MXP -> NQY (308/1000) ...
# Fetching MXP -> LDN (309/1000) ...
# Fetching MXP -> CGO (310/1000) ...
# Fetching MXP -> DSS (311/1000) ...
# Fetching MXP -> YRI (312/1000) ...
# Error fetching MXP -> YRI: [400]
#
# Fetching MXP -> UNK (313/1000) ...
# Fetching MXP -> PDV (314/1000) ...
# Fetching MXP -> KVR (315/1000) ...
# Error fetching MXP -> KVR: [400]
#
# Fetching MXP -> FUN (316/1000) ...
# Error fetching MXP -> FUN: [400]
#
# Fetching MXP -> UTH (317/1000) ...
# Fetching MXP -> MPN (318/1000) ...
# Error fetching MXP -> MPN: [400]
#
# Fetching MXP -> KXF (319/1000) ...
# Error fetching MXP -> KXF: [400]
#
# Fetching MXP -> BIG (320/1000) ...
# Fetching MXP -> OKF (321/1000) ...
# Fetching MXP -> WMO (322/1000) ...
# Error fetching MXP -> WMO: [400]
#
# Fetching MXP -> HBX (323/1000) ...
# Fetching MXP -> MXS (324/1000) ...
# Fetching MXP -> MDR (325/1000) ...
# Fetching MXP -> SCX (326/1000) ...
# Fetching MXP -> MFM (327/1000) ...
# Fetching MXP -> GRP (328/1000) ...
# Fetching MXP -> WAE (329/1000) ...
# Fetching MXP -> TCB (330/1000) ...
# Error fetching MXP -> TCB: [400]
#
# Fetching MXP -> IOM (331/1000) ...
# Fetching MXP -> KQT (332/1000) ...
# Error fetching MXP -> KQT: [400]
#
# Fetching MXP -> WUB (333/1000) ...
# Fetching MXP -> HFA (334/1000) ...
# Fetching MXP -> WRY (335/1000) ...
# Error fetching MXP -> WRY: [400]
#
# Fetching MXP -> CKH (336/1000) ...
# Error fetching MXP -> CKH: [400]
#
# Fetching MXP -> KIH (337/1000) ...
# Fetching MXP -> TNO (338/1000) ...
# Fetching MXP -> RHI (339/1000) ...
# Fetching MXP -> AIU (340/1000) ...
# Fetching MXP -> NNT (341/1000) ...
# Fetching MXP -> RAM (342/1000) ...
# Fetching MXP -> ONS (343/1000) ...
# Fetching MXP -> NON (344/1000) ...
# Error fetching MXP -> NON: [400]
#
# Fetching MXP -> EFD (345/1000) ...
# Fetching MXP -> RIZ (346/1000) ...
# Error fetching MXP -> RIZ: [400]
#
# Fetching MXP -> BPG (347/1000) ...
# Error fetching MXP -> BPG: [400]
#
# Fetching MXP -> WHD (348/1000) ...
# Error fetching MXP -> WHD: [400]
#
# Fetching MXP -> LRT (349/1000) ...
# Fetching MXP -> TNA (350/1000) ...
# Autosaved 350 airports to airports_with_prices.csv
# Fetching MXP -> NTL (351/1000) ...
# Fetching MXP -> TRG (352/1000) ...
# Fetching MXP -> CPH (353/1000) ...
# Fetching MXP -> MEI (354/1000) ...
# Error fetching MXP -> MEI: [400]
#
# Fetching MXP -> COQ (355/1000) ...
# Error fetching MXP -> COQ: [400]
#
# Fetching MXP -> ELI (356/1000) ...
# Error fetching MXP -> ELI: [400]
#
# Fetching MXP -> VIN (357/1000) ...
# Error fetching MXP -> VIN: [400]
#
# Fetching MXP -> VTU (358/1000) ...
# Fetching MXP -> YQL (359/1000) ...
# Error fetching MXP -> YQL: [400]
#
# Fetching MXP -> XGR (360/1000) ...
# Error fetching MXP -> XGR: [400]
#
# Fetching MXP -> WBM (361/1000) ...
# Error fetching MXP -> WBM: [400]
#
# Fetching MXP -> NAG (362/1000) ...
# Fetching MXP -> CMV (363/1000) ...
# Error fetching MXP -> CMV: [400]
#
# Fetching MXP -> HOT (364/1000) ...
# Fetching MXP -> CCU (365/1000) ...
# Fetching MXP -> MFE (366/1000) ...
# Fetching MXP -> PBC (367/1000) ...
# Fetching MXP -> SMN (368/1000) ...
# Fetching MXP -> YTS (369/1000) ...
# Fetching MXP -> LUZ (370/1000) ...
# Error fetching MXP -> LUZ: [400]
#
# Fetching MXP -> ATY (371/1000) ...
# Fetching MXP -> JOK (372/1000) ...
# Error fetching MXP -> JOK: [400]
#
# Fetching MXP -> LVA (373/1000) ...
# Fetching MXP -> MZJ (374/1000) ...
# Error fetching MXP -> MZJ: [400]
#
# Fetching MXP -> BNA (375/1000) ...
# Fetching MXP -> SKG (376/1000) ...
# Fetching MXP -> TKX (377/1000) ...
# Error fetching MXP -> TKX: [400]
#
# Fetching MXP -> VRY (378/1000) ...
# Error fetching MXP -> VRY: [400]
#
# Fetching MXP -> MCP (379/1000) ...
# Fetching MXP -> GBB (380/1000) ...
# Fetching MXP -> MMJ (381/1000) ...
# Fetching MXP -> SOD (382/1000) ...
# Fetching MXP -> CHG (383/1000) ...
# Fetching MXP -> CEB (384/1000) ...
# Fetching MXP -> RLG (385/1000) ...
# Fetching MXP -> HAN (386/1000) ...
# Fetching MXP -> EKO (387/1000) ...
# Error fetching MXP -> EKO: [400]
#
# Fetching MXP -> WUU (388/1000) ...
# Error fetching MXP -> WUU: [400]
#
# Fetching MXP -> LDG (389/1000) ...
# Error fetching MXP -> LDG: [400]
#
# Fetching MXP -> YHF (390/1000) ...
# Error fetching MXP -> YHF: [400]
#
# Fetching MXP -> QXG (391/1000) ...
# Error fetching MXP -> QXG: [400]
#
# Fetching MXP -> JHB (392/1000) ...
# Fetching MXP -> BOT (393/1000) ...
# Fetching MXP -> QNJ (394/1000) ...
# Error fetching MXP -> QNJ: [400]
#
# Fetching MXP -> LVM (395/1000) ...
# Error fetching MXP -> LVM: [400]
#
# Fetching MXP -> GES (396/1000) ...
# Fetching MXP -> MZK (397/1000) ...
# Fetching MXP -> BWI (398/1000) ...
# Fetching MXP -> KKD (399/1000) ...
# Error fetching MXP -> KKD: [400]
#
# Fetching MXP -> ARH (400/1000) ...
# Error fetching MXP -> ARH: [400]
#
# Autosaved 400 airports to airports_with_prices.csv
# Fetching MXP -> YAZ (401/1000) ...
# Error fetching MXP -> YAZ: [400]
#
# Fetching MXP -> WTN (402/1000) ...
# Error fetching MXP -> WTN: [400]
#
# Fetching MXP -> YES (403/1000) ...
# Fetching MXP -> QUB (404/1000) ...
# Error fetching MXP -> QUB: [400]
#
# Fetching MXP -> XYK (405/1000) ...
# Fetching MXP -> AFL (406/1000) ...
# Error fetching MXP -> AFL: [400]
#
# Fetching MXP -> CUK (407/1000) ...
# Error fetching MXP -> CUK: [400]
#
# Fetching MXP -> HUS (408/1000) ...
# Error fetching MXP -> HUS: [400]
#
# Fetching MXP -> JSR (409/1000) ...
# Fetching MXP -> OST (410/1000) ...
# Error fetching MXP -> OST: [400]
#
# Fetching MXP -> PVE (411/1000) ...
# Fetching MXP -> UUA (412/1000) ...
# Fetching MXP -> MDP (413/1000) ...
# Fetching MXP -> HHR (414/1000) ...
# Fetching MXP -> YRQ (415/1000) ...
# Fetching MXP -> TDL (416/1000) ...
# Fetching MXP -> ELU (417/1000) ...
# Fetching MXP -> UKU (418/1000) ...
# Fetching MXP -> ZKP (419/1000) ...
# Fetching MXP -> PUF (420/1000) ...
# Fetching MXP -> DCY (421/1000) ...
# Error fetching MXP -> DCY: [400]
#
# Fetching MXP -> TAN (422/1000) ...
# Error fetching MXP -> TAN: [400]
#
# Fetching MXP -> YDQ (423/1000) ...
# Fetching MXP -> SOF (424/1000) ...
# Fetching MXP -> SAC (425/1000) ...
# Fetching MXP -> GBT (426/1000) ...
# Error fetching MXP -> GBT: [400]
#
# Fetching MXP -> DIY (427/1000) ...
# Fetching MXP -> MWA (428/1000) ...
# Fetching MXP -> COT (429/1000) ...
# Fetching MXP -> PPN (430/1000) ...
# Fetching MXP -> TGT (431/1000) ...
# Error fetching MXP -> TGT: [400]
#
# Fetching MXP -> TKM (432/1000) ...
# Error fetching MXP -> TKM: [400]
#
# Fetching MXP -> VSG (433/1000) ...
# Error fetching MXP -> VSG: [400]
#
# Fetching MXP -> GUD (434/1000) ...
# Error fetching MXP -> GUD: [400]
#
# Fetching MXP -> FCA (435/1000) ...
# Fetching MXP -> YMK (436/1000) ...
# Error fetching MXP -> YMK: [400]
#
# Fetching MXP -> YEC (437/1000) ...
# Fetching MXP -> CPB (438/1000) ...
# Error fetching MXP -> CPB: [400]
#
# Fetching MXP -> FNC (439/1000) ...
# Fetching MXP -> YQW (440/1000) ...
# Fetching MXP -> DHI (441/1000) ...
# Error fetching MXP -> DHI: [400]
#
# Fetching MXP -> CIZ (442/1000) ...
# Fetching MXP -> SAW (443/1000) ...
# Fetching MXP -> YBY (444/1000) ...
# Fetching MXP -> DOL (445/1000) ...
# Fetching MXP -> GCN (446/1000) ...
# Fetching MXP -> YLX (447/1000) ...
# Fetching MXP -> TFI (448/1000) ...
# Error fetching MXP -> TFI: [400]
#
# Fetching MXP -> OCF (449/1000) ...
# Fetching MXP -> IST (450/1000) ...
# Autosaved 450 airports to airports_with_prices.csv
# Fetching MXP -> BTO (451/1000) ...
# Fetching MXP -> TDD (452/1000) ...
# Fetching MXP -> DZN (453/1000) ...
# Error fetching MXP -> DZN: [400]
#
# Fetching MXP -> - (454/1000) ...
# Error fetching MXP -> -: [400]
#
# Fetching MXP -> CXL (455/1000) ...
# Error fetching MXP -> CXL: [400]
#
# Fetching MXP -> AGF (456/1000) ...
# Fetching MXP -> ORN (457/1000) ...
# Fetching MXP -> ADX (458/1000) ...
# Error fetching MXP -> ADX: [400]
#
# Fetching MXP -> YAW (459/1000) ...
# Fetching MXP -> EDA (460/1000) ...
# Error fetching MXP -> EDA: [400]
#
# Fetching MXP -> YGL (461/1000) ...
# Fetching MXP -> AFS (462/1000) ...
# Error fetching MXP -> AFS: [400]
#
# Fetching MXP -> KEN (463/1000) ...
# Error fetching MXP -> KEN: [400]
#
# Fetching MXP -> FMH (464/1000) ...
# Fetching MXP -> SPS (465/1000) ...
# Error fetching MXP -> SPS: [400]
#
# Fetching MXP -> KZI (466/1000) ...
# Fetching MXP -> CMD (467/1000) ...
# Fetching MXP -> ENC (468/1000) ...
# Fetching MXP -> AMH (469/1000) ...
# Fetching MXP -> JHG (470/1000) ...
# Fetching MXP -> TAL (471/1000) ...
# Error fetching MXP -> TAL: [400]
#
# Fetching MXP -> REC (472/1000) ...
# Fetching MXP -> CXP (473/1000) ...
# Fetching MXP -> NQA (474/1000) ...
# Error fetching MXP -> NQA: [400]
#
# Fetching MXP -> YOO (475/1000) ...
# Error fetching MXP -> YOO: [400]
#
# Fetching MXP -> TYQ (476/1000) ...
# Fetching MXP -> NEW (477/1000) ...
# Fetching MXP -> TMK (478/1000) ...
# Fetching MXP -> POR (479/1000) ...
# Fetching MXP -> AOG (480/1000) ...
# Error fetching MXP -> AOG: [400]
#
# Fetching MXP -> SMX (481/1000) ...
# Error fetching MXP -> SMX: [400]
#
# Fetching MXP -> GDW (482/1000) ...
# Fetching MXP -> HMV (483/1000) ...
# Error fetching MXP -> HMV: [400]
#
# Fetching MXP -> JMU (484/1000) ...
# Error fetching MXP -> JMU: [400]
#
# Fetching MXP -> ASP (485/1000) ...
# Fetching MXP -> TMX (486/1000) ...
# Fetching MXP -> PVU (487/1000) ...
# Fetching MXP -> YXT (488/1000) ...
# Error fetching MXP -> YXT: [400]
#
# Fetching MXP -> UKT (489/1000) ...
# Error fetching MXP -> UKT: [400]
#
# Fetching MXP -> NBC (490/1000) ...
# Error fetching MXP -> NBC: [400]
#
# Fetching MXP -> CKB (491/1000) ...
# Error fetching MXP -> CKB: [400]
#
# Fetching MXP -> ROB (492/1000) ...
# Fetching MXP -> COV (493/1000) ...
# Fetching MXP -> TUU (494/1000) ...
# Fetching MXP -> MLA (495/1000) ...
# Fetching MXP -> SRA (496/1000) ...
# Error fetching MXP -> SRA: [400]
#
# Fetching MXP -> SAK (497/1000) ...
# Fetching MXP -> GKA (498/1000) ...
# Fetching MXP -> LJA (499/1000) ...
# Error fetching MXP -> LJA: [400]
#
# Fetching MXP -> WMN (500/1000) ...
# Error fetching MXP -> WMN: [400]
#
# Autosaved 500 airports to airports_with_prices.csv
# Fetching MXP -> EAA (501/1000) ...
# Fetching MXP -> AHO (502/1000) ...
# Error fetching MXP -> AHO: [400]
#
# Fetching MXP -> PHA (503/1000) ...
# Fetching MXP -> ULC (504/1000) ...
# Error fetching MXP -> ULC: [400]
#
# Fetching MXP -> KEJ (505/1000) ...
# Fetching MXP -> PAZ (506/1000) ...
# Fetching MXP -> PPL (507/1000) ...
# Fetching MXP -> ROP (508/1000) ...
# Fetching MXP -> PSR (509/1000) ...
# Error fetching MXP -> PSR: [400]
#
# Fetching MXP -> NMA (510/1000) ...
# Fetching MXP -> VDS (511/1000) ...
# Error fetching MXP -> VDS: [400]
#
# Fetching MXP -> SUR (512/1000) ...
# Error fetching MXP -> SUR: [400]
#
# Fetching MXP -> GTO (513/1000) ...
# Error fetching MXP -> GTO: [400]
#
# Fetching MXP -> CGK (514/1000) ...
# Fetching MXP -> OLB (515/1000) ...
# Fetching MXP -> DOK (516/1000) ...
# Fetching MXP -> CCM (517/1000) ...
# Fetching MXP -> SJI (518/1000) ...
# Fetching MXP -> SUV (519/1000) ...
# Fetching MXP -> UGA (520/1000) ...
# Error fetching MXP -> UGA: [400]
#
# Fetching MXP -> EPU (521/1000) ...
# Error fetching MXP -> EPU: [400]
#
# Fetching MXP -> FLW (522/1000) ...
# Error fetching MXP -> FLW: [400]
#
# Fetching MXP -> ADD (523/1000) ...
# Fetching MXP -> HRT (524/1000) ...
# Error fetching MXP -> HRT: [400]
#
# Fetching MXP -> EVV (525/1000) ...
# Fetching MXP -> YYC (526/1000) ...
# Fetching MXP -> DNV (527/1000) ...
# Fetching MXP -> PKP (528/1000) ...
# Error fetching MXP -> PKP: [400]
#
# Fetching MXP -> GSA (529/1000) ...
# Fetching MXP -> AIN (530/1000) ...
# Fetching MXP -> CAH (531/1000) ...
# Error fetching MXP -> CAH: [400]
#
# Fetching MXP -> MCM (532/1000) ...
# Fetching MXP -> EBL (533/1000) ...
# Fetching MXP -> SFB (534/1000) ...
# Error fetching MXP -> SFB: [400]
#
# Fetching MXP -> BRX (535/1000) ...
# Error fetching MXP -> BRX: [400]
#
# Fetching MXP -> SAX (536/1000) ...
# Fetching MXP -> WIO (537/1000) ...
# Error fetching MXP -> WIO: [400]
#
# Fetching MXP -> SME (538/1000) ...
# Fetching MXP -> SXF (539/1000) ...
# Error fetching MXP -> SXF: [400]
#
# Fetching MXP -> OOK (540/1000) ...
# Error fetching MXP -> OOK: [400]
#
# Fetching MXP -> TVY (541/1000) ...
# Fetching MXP -> MEU (542/1000) ...
# Fetching MXP -> CRA (543/1000) ...
# Error fetching MXP -> CRA: [400]
#
# Fetching MXP -> YAV (544/1000) ...
# Error fetching MXP -> YAV: [400]
#
# Fetching MXP -> BET (545/1000) ...
# Fetching MXP -> PAY (546/1000) ...
# Error fetching MXP -> PAY: [400]
#
# Fetching MXP -> INK (547/1000) ...
# Error fetching MXP -> INK: [400]
#
# Fetching MXP -> MHE (548/1000) ...
# Error fetching MXP -> MHE: [400]
#
# Fetching MXP -> ESF (549/1000) ...
# Error fetching MXP -> ESF: [400]
#
# Fetching MXP -> QGN (550/1000) ...
# Error fetching MXP -> QGN: [400]
#
# Autosaved 550 airports to airports_with_prices.csv
# Fetching MXP -> QDH (551/1000) ...
# Error fetching MXP -> QDH: [400]
#
# Fetching MXP -> KXA (552/1000) ...
# Error fetching MXP -> KXA: [400]
#
# Fetching MXP -> GHB (553/1000) ...
# Error fetching MXP -> GHB: [400]
#
# Fetching MXP -> NDA (554/1000) ...
# Error fetching MXP -> NDA: [400]
#
# Fetching MXP -> LMJ (555/1000) ...
# Error fetching MXP -> LMJ: [400]
#
# Fetching MXP -> BJC (556/1000) ...
# Error fetching MXP -> BJC: [400]
#
# Fetching MXP -> VBT (557/1000) ...
# Error fetching MXP -> VBT: [400]
#
# Fetching MXP -> JBU (558/1000) ...
# Fetching MXP -> IHU (559/1000) ...
# Fetching MXP -> LDJ (560/1000) ...
# Error fetching MXP -> LDJ: [400]
#
# Fetching MXP -> IZO (561/1000) ...
# Fetching MXP -> SLL (562/1000) ...
# Fetching MXP -> XDK (563/1000) ...
# Fetching MXP -> SVX (564/1000) ...
# Fetching MXP -> CLN (565/1000) ...
# Error fetching MXP -> CLN: [400]
#
# Fetching MXP -> NDZ (566/1000) ...
# Error fetching MXP -> NDZ: [400]
#
# Fetching MXP -> GSQ (567/1000) ...
# Error fetching MXP -> GSQ: [400]
#
# Fetching MXP -> ORA (568/1000) ...
# Error fetching MXP -> ORA: [400]
#
# Fetching MXP -> IMM (569/1000) ...
# Error fetching MXP -> IMM: [400]
#
# Fetching MXP -> PEN (570/1000) ...
# Fetching MXP -> TIM (571/1000) ...
# Fetching MXP -> PAF (572/1000) ...
# Error fetching MXP -> PAF: [400]
#
# Fetching MXP -> TMB (573/1000) ...
# Fetching MXP -> ISE (574/1000) ...
# Fetching MXP -> HLY (575/1000) ...
# Fetching MXP -> LTX (576/1000) ...
# Error fetching MXP -> LTX: [400]
#
# Fetching MXP -> ORX (577/1000) ...
# Error fetching MXP -> ORX: [400]
#
# Fetching MXP -> ODY (578/1000) ...
# Fetching MXP -> AKY (579/1000) ...
# Fetching MXP -> SKH (580/1000) ...
# Fetching MXP -> UDJ (581/1000) ...
# Error fetching MXP -> UDJ: [400]
#
# Fetching MXP -> BWU (582/1000) ...
# Fetching MXP -> ARV (583/1000) ...
# Error fetching MXP -> ARV: [400]
#
# Fetching MXP -> ISB (584/1000) ...
# Fetching MXP -> NAJ (585/1000) ...
# Error fetching MXP -> NAJ: [400]
#
# Fetching MXP -> HOR (586/1000) ...
# Error fetching MXP -> HOR: [400]
#
# Fetching MXP -> FNT (587/1000) ...
# Error fetching MXP -> FNT: [400]
#
# Fetching MXP -> ELG (588/1000) ...
# Error fetching MXP -> ELG: [400]
#
# Fetching MXP -> LRV (589/1000) ...
# Fetching MXP -> YCO (590/1000) ...
# Fetching MXP -> MSL (591/1000) ...
# Fetching MXP -> VQQ (592/1000) ...
# Fetching MXP -> WUN (593/1000) ...
# Fetching MXP -> VRC (594/1000) ...
# Fetching MXP -> DMK (595/1000) ...
# Fetching MXP -> AAS (596/1000) ...
# Error fetching MXP -> AAS: [400]
#
# Fetching MXP -> YXD (597/1000) ...
# Fetching MXP -> KDY (598/1000) ...
# Fetching MXP -> JLR (599/1000) ...
# Fetching MXP -> LAY (600/1000) ...
# Autosaved 600 airports to airports_with_prices.csv
# Fetching MXP -> AKK (601/1000) ...
# Error fetching MXP -> AKK: [400]
#
# Fetching MXP -> CZS (602/1000) ...
# Error fetching MXP -> CZS: [400]
#
# Fetching MXP -> CMA (603/1000) ...
# Error fetching MXP -> CMA: [400]
#
# Fetching MXP -> LSA (604/1000) ...
# Error fetching MXP -> LSA: [400]
#
# Fetching MXP -> ВГЖ (605/1000) ...
# Error fetching MXP -> ВГЖ: [400]
#
# Fetching MXP -> GOM (606/1000) ...
# Fetching MXP -> OSL (607/1000) ...
# Fetching MXP -> PIO (608/1000) ...
# Error fetching MXP -> PIO: [400]
#
# Fetching MXP -> AVL (609/1000) ...
# Fetching MXP -> COS (610/1000) ...
# Fetching MXP -> BZZ (611/1000) ...
# Fetching MXP -> EZV (612/1000) ...
# Fetching MXP -> NLI (613/1000) ...
# Error fetching MXP -> NLI: [400]
#
# Fetching MXP -> IOA (614/1000) ...
# Fetching MXP -> YRJ (615/1000) ...
# Error fetching MXP -> YRJ: [400]
#
# Fetching MXP -> LGW (616/1000) ...
# Fetching MXP -> XMS (617/1000) ...
# Error fetching MXP -> XMS: [400]
#
# Fetching MXP -> SIS (618/1000) ...
# Fetching MXP -> QLA (619/1000) ...
# Fetching MXP -> ECA (620/1000) ...
# Fetching MXP -> POM (621/1000) ...
# Fetching MXP -> NRL (622/1000) ...
# Error fetching MXP -> NRL: [400]
#
# Fetching MXP -> UAP (623/1000) ...
# Fetching MXP -> OBD (624/1000) ...
# Error fetching MXP -> OBD: [400]
#
# Fetching MXP -> OLK (625/1000) ...
# Fetching MXP -> CAJ (626/1000) ...
# Fetching MXP -> BZY (627/1000) ...
# Fetching MXP -> AQG (628/1000) ...
# Error fetching MXP -> AQG: [400]
#
# Fetching MXP -> FMI (629/1000) ...
# Error fetching MXP -> FMI: [400]
#
# Fetching MXP -> HYG (630/1000) ...
# Fetching MXP -> TSV (631/1000) ...
# Fetching MXP -> WLK (632/1000) ...
# Error fetching MXP -> WLK: [400]
#
# Fetching MXP -> BVB (633/1000) ...
# Fetching MXP -> PEW (634/1000) ...
# Fetching MXP -> HOG (635/1000) ...
# Error fetching MXP -> HOG: [400]
#
# Fetching MXP -> ZAJ (636/1000) ...
# Error fetching MXP -> ZAJ: [400]
#
# Fetching MXP -> YKZ (637/1000) ...
# Error fetching MXP -> YKZ: [400]
#
# Fetching MXP -> PGX (638/1000) ...
# Error fetching MXP -> PGX: [400]
#
# Fetching MXP -> KKU (639/1000) ...
# Error fetching MXP -> KKU: [400]
#
# Fetching MXP -> UKY (640/1000) ...
# Error fetching MXP -> UKY: [400]
#
# Fetching MXP -> FMN (641/1000) ...
# Error fetching MXP -> FMN: [400]
#
# Fetching MXP -> LXR (642/1000) ...
# Fetching MXP -> HAE (643/1000) ...
# Fetching MXP -> NDY (644/1000) ...
# Fetching MXP -> UEO (645/1000) ...
# Error fetching MXP -> UEO: [400]
#
# Fetching MXP -> BSC (646/1000) ...
# Fetching MXP -> SVU (647/1000) ...
# Fetching MXP -> HFS (648/1000) ...
# Fetching MXP -> OIR (649/1000) ...
# Fetching MXP -> IFO (650/1000) ...
# Autosaved 650 airports to airports_with_prices.csv
# Fetching MXP -> NYI (651/1000) ...
# Fetching MXP -> RVK (652/1000) ...
# Error fetching MXP -> RVK: [400]
#
# Fetching MXP -> ORT (653/1000) ...
# Fetching MXP -> HTA (654/1000) ...
# Error fetching MXP -> HTA: [400]
#
# Fetching MXP -> ZPQ (655/1000) ...
# Fetching MXP -> ESE (656/1000) ...
# Error fetching MXP -> ESE: [400]
#
# Fetching MXP -> XKS (657/1000) ...
# Fetching MXP -> TOJ (658/1000) ...
# Fetching MXP -> AGQ (659/1000) ...
# Error fetching MXP -> AGQ: [400]
#
# Fetching MXP -> SQJ (660/1000) ...
# Error fetching MXP -> SQJ: [400]
#
# Fetching MXP -> KEV (661/1000) ...
# Error fetching MXP -> KEV: [400]
#
# Fetching MXP -> ROK (662/1000) ...
# Fetching MXP -> PPK (663/1000) ...
# Fetching MXP -> YSC (664/1000) ...
# Error fetching MXP -> YSC: [400]
#
# Fetching MXP -> AAN (665/1000) ...
# Fetching MXP -> BFS (666/1000) ...
# Fetching MXP -> PSH (667/1000) ...
# Fetching MXP -> TAM (668/1000) ...
# Fetching MXP -> PHN (669/1000) ...
# Fetching MXP -> YLT (670/1000) ...
# Error fetching MXP -> YLT: [400]
#
# Fetching MXP -> XBJ (671/1000) ...
# Fetching MXP -> RBE (672/1000) ...
# Fetching MXP -> GZP (673/1000) ...
# Fetching MXP -> JAT (674/1000) ...
# Error fetching MXP -> JAT: [400]
#
# Fetching MXP -> QHR (675/1000) ...
# Error fetching MXP -> QHR: [400]
#
# Fetching MXP -> RBB (676/1000) ...
# Error fetching MXP -> RBB: [400]
#
# Fetching MXP -> LVO (677/1000) ...
# Error fetching MXP -> LVO: [400]
#
# Fetching MXP -> TIV (678/1000) ...
# Fetching MXP -> STB (679/1000) ...
# Error fetching MXP -> STB: [400]
#
# Fetching MXP -> LSY (680/1000) ...
# Fetching MXP -> PRX (681/1000) ...
# Fetching MXP -> TJM (682/1000) ...
# Fetching MXP -> HUU (683/1000) ...
# Fetching MXP -> YAG (684/1000) ...
# Fetching MXP -> KDM (685/1000) ...
# Fetching MXP -> RHO (686/1000) ...
# Fetching MXP -> ODS (687/1000) ...
# Fetching MXP -> ACS (688/1000) ...
# Error fetching MXP -> ACS: [400]
#
# Fetching MXP -> GED (689/1000) ...
# Error fetching MXP -> GED: [400]
#
# Fetching MXP -> RXS (690/1000) ...
# Fetching MXP -> UKG (691/1000) ...
# Error fetching MXP -> UKG: [400]
#
# Fetching MXP -> MAS (692/1000) ...
# Error fetching MXP -> MAS: [400]
#
# Fetching MXP -> RPN (693/1000) ...
# Error fetching MXP -> RPN: [400]
#
# Fetching MXP -> PUZ (694/1000) ...
# Error fetching MXP -> PUZ: [400]
#
# Fetching MXP -> MBP (695/1000) ...
# Error fetching MXP -> MBP: [400]
#
# Fetching MXP -> KDA (696/1000) ...
# Fetching MXP -> XLS (697/1000) ...
# Error fetching MXP -> XLS: [400]
#
# Fetching MXP -> LNX (698/1000) ...
# Error fetching MXP -> LNX: [400]
#
# Fetching MXP -> RNO (699/1000) ...
# Fetching MXP -> ASO (700/1000) ...
# Error fetching MXP -> ASO: [400]
#
# Autosaved 700 airports to airports_with_prices.csv
# Fetching MXP -> LNE (701/1000) ...
# Fetching MXP -> LCH (702/1000) ...
# Fetching MXP -> OBU (703/1000) ...
# Error fetching MXP -> OBU: [400]
#
# Fetching MXP -> RNJ (704/1000) ...
# Fetching MXP -> GPZ (705/1000) ...
# Error fetching MXP -> GPZ: [400]
#
# Fetching MXP -> ASB (706/1000) ...
# Fetching MXP -> LCA (707/1000) ...
# Fetching MXP -> XRY (708/1000) ...
# Fetching MXP -> ENA (709/1000) ...
# Fetching MXP -> nan (710/1000) ...
# Error fetching MXP -> nan: [400]
#
# Fetching MXP -> AKX (711/1000) ...
# Fetching MXP -> VHC (712/1000) ...
# Error fetching MXP -> VHC: [400]
#
# Fetching MXP -> MPV (713/1000) ...
# Fetching MXP -> IXH (714/1000) ...
# Fetching MXP -> YEU (715/1000) ...
# Error fetching MXP -> YEU: [400]
#
# Fetching MXP -> KNX (716/1000) ...
# Fetching MXP -> SHY (717/1000) ...
# Error fetching MXP -> SHY: [400]
#
# Fetching MXP -> AIZ (718/1000) ...
# Fetching MXP -> MAK (719/1000) ...
# Error fetching MXP -> MAK: [400]
#
# Fetching MXP -> DTU (720/1000) ...
# Fetching MXP -> ZQW (721/1000) ...
# Fetching MXP -> HRN (722/1000) ...
# Error fetching MXP -> HRN: [400]
#
# Fetching MXP -> SFL (723/1000) ...
# Error fetching MXP -> SFL: [400]
#
# Fetching MXP -> ZAU (724/1000) ...
# Error fetching MXP -> ZAU: [400]
#
# Fetching MXP -> PBH (725/1000) ...
# Fetching MXP -> ZEG (726/1000) ...
# Error fetching MXP -> ZEG: [400]
#
# Fetching MXP -> NAV (727/1000) ...
# Fetching MXP -> TGP (728/1000) ...
# Fetching MXP -> TGK (729/1000) ...
# Error fetching MXP -> TGK: [400]
#
# Fetching MXP -> ZWL (730/1000) ...
# Error fetching MXP -> ZWL: [400]
#
# Fetching MXP -> KDR (731/1000) ...
# Error fetching MXP -> KDR: [400]
#
# Fetching MXP -> UTC (732/1000) ...
# Error fetching MXP -> UTC: [400]
#
# Fetching MXP -> YGH (733/1000) ...
# Error fetching MXP -> YGH: [400]
#
# Fetching MXP -> EGS (734/1000) ...
# Fetching MXP -> STZ (735/1000) ...
# Error fetching MXP -> STZ: [400]
#
# Fetching MXP -> KWT (736/1000) ...
# Error fetching MXP -> KWT: [400]
#
# Fetching MXP -> BDJ (737/1000) ...
# Error fetching MXP -> BDJ: [400]
#
# Fetching MXP -> SLH (738/1000) ...
# Error fetching MXP -> SLH: [400]
#
# Fetching MXP -> SHP (739/1000) ...
# Fetching MXP -> BHA (740/1000) ...
# Error fetching MXP -> BHA: [400]
#
# Fetching MXP -> LXG (741/1000) ...
# Fetching MXP -> ZMP (742/1000) ...
# Fetching MXP -> KKA (743/1000) ...
# Fetching MXP -> CXY (744/1000) ...
# Error fetching MXP -> CXY: [400]
#
# Fetching MXP -> BEP (745/1000) ...
# Error fetching MXP -> BEP: [400]
#
# Fetching MXP -> SVH (746/1000) ...
# Fetching MXP -> TCH (747/1000) ...
# Fetching MXP -> MME (748/1000) ...
# Fetching MXP -> RCH (749/1000) ...
# Fetching MXP -> ZAL (750/1000) ...
# Error fetching MXP -> ZAL: [400]
#
# Autosaved 750 airports to airports_with_prices.csv
# Fetching MXP -> GJL (751/1000) ...
# Error fetching MXP -> GJL: [400]
#
# Fetching MXP -> TIP (752/1000) ...
# Fetching MXP -> SKF (753/1000) ...
# Fetching MXP -> KOC (754/1000) ...
# Error fetching MXP -> KOC: [400]
#
# Fetching MXP -> BRI (755/1000) ...
# Fetching MXP -> VIX (756/1000) ...
# Fetching MXP -> XCD (757/1000) ...
# Error fetching MXP -> XCD: [400]
#
# Fetching MXP -> JVA (758/1000) ...
# Error fetching MXP -> JVA: [400]
#
# Fetching MXP -> MOV (759/1000) ...
# Fetching MXP -> JER (760/1000) ...
# Fetching MXP -> SVJ (761/1000) ...
# Error fetching MXP -> SVJ: [400]
#
# Fetching MXP -> GRS (762/1000) ...
# Fetching MXP -> LBS (763/1000) ...
# Error fetching MXP -> LBS: [400]
#
# Fetching MXP -> NNG (764/1000) ...
# Fetching MXP -> PVH (765/1000) ...
# Fetching MXP -> TVL (766/1000) ...
# Error fetching MXP -> TVL: [400]
#
# Fetching MXP -> BAR (767/1000) ...
# Error fetching MXP -> BAR: [400]
#
# Fetching MXP -> XAU (768/1000) ...
# Fetching MXP -> DBM (769/1000) ...
# Fetching MXP -> CKY (770/1000) ...
# Fetching MXP -> NVK (771/1000) ...
# Error fetching MXP -> NVK: [400]
#
# Fetching MXP -> GHU (772/1000) ...
# Fetching MXP -> БГБ (773/1000) ...
# Error fetching MXP -> БГБ: [400]
#
# Fetching MXP -> YKQ (774/1000) ...
# Error fetching MXP -> YKQ: [400]
#
# Fetching MXP -> TMH (775/1000) ...
# Fetching MXP -> RYN (776/1000) ...
# Fetching MXP -> EIL (777/1000) ...
# Fetching MXP -> LYI (778/1000) ...
# Fetching MXP -> TKJ (779/1000) ...
# Error fetching MXP -> TKJ: [400]
#
# Fetching MXP -> YZX (780/1000) ...
# Error fetching MXP -> YZX: [400]
#
# Fetching MXP -> RML (781/1000) ...
# Fetching MXP -> PMF (782/1000) ...
# Fetching MXP -> QVY (783/1000) ...
# Error fetching MXP -> QVY: [400]
#
# Fetching MXP -> KOE (784/1000) ...
# Error fetching MXP -> KOE: [400]
#
# Fetching MXP -> ASA (785/1000) ...
# Error fetching MXP -> ASA: [400]
#
# Fetching MXP -> KBJ (786/1000) ...
# Error fetching MXP -> KBJ: [400]
#
# Fetching MXP -> HPA (787/1000) ...
# Error fetching MXP -> HPA: [400]
#
# Fetching MXP -> KZO (788/1000) ...
# Fetching MXP -> RAZ (789/1000) ...
# Fetching MXP -> BRS (790/1000) ...
# Fetching MXP -> ULN (791/1000) ...
# Fetching MXP -> YYH (792/1000) ...
# Error fetching MXP -> YYH: [400]
#
# Fetching MXP -> PKB (793/1000) ...
# Error fetching MXP -> PKB: [400]
#
# Fetching MXP -> KVB (794/1000) ...
# Error fetching MXP -> KVB: [400]
#
# Fetching MXP -> SUN (795/1000) ...
# Fetching MXP -> PEE (796/1000) ...
# Fetching MXP -> AYK (797/1000) ...
# Fetching MXP -> TKN (798/1000) ...
# Fetching MXP -> GHT (799/1000) ...
# Error fetching MXP -> GHT: [400]
#
# Fetching MXP -> IWS (800/1000) ...
# Autosaved 800 airports to airports_with_prices.csv
# Fetching MXP -> OFU (801/1000) ...
# Error fetching MXP -> OFU: [400]
#
# Fetching MXP -> PNP (802/1000) ...
# Error fetching MXP -> PNP: [400]
#
# Fetching MXP -> AMY (803/1000) ...
# Error fetching MXP -> AMY: [400]
#
# Fetching MXP -> OMH (804/1000) ...
# Error fetching MXP -> OMH: [400]
#
# Fetching MXP -> TPA (805/1000) ...
# Fetching MXP -> MHU (806/1000) ...
# Error fetching MXP -> MHU: [400]
#
# Fetching MXP -> LRD (807/1000) ...
# Fetching MXP -> LJU (808/1000) ...
# Fetching MXP -> HOU (809/1000) ...
# Fetching MXP -> ASE (810/1000) ...
# Fetching MXP -> BVG (811/1000) ...
# Fetching MXP -> YVQ (812/1000) ...
# Error fetching MXP -> YVQ: [400]
#
# Fetching MXP -> YHC (813/1000) ...
# Fetching MXP -> RND (814/1000) ...
# Error fetching MXP -> RND: [400]
#
# Fetching MXP -> LIS (815/1000) ...
# Fetching MXP -> DMU (816/1000) ...
# Error fetching MXP -> DMU: [400]
#
# Fetching MXP -> ANU (817/1000) ...
# Fetching MXP -> YVM (818/1000) ...
# Error fetching MXP -> YVM: [400]
#
# Fetching MXP -> INL (819/1000) ...
# Error fetching MXP -> INL: [400]
#
# Fetching MXP -> CWT (820/1000) ...
# Error fetching MXP -> CWT: [400]
#
# Fetching MXP -> EGO (821/1000) ...
# Error fetching MXP -> EGO: [400]
#
# Fetching MXP -> NLP (822/1000) ...
# Error fetching MXP -> NLP: [400]
#
# Fetching MXP -> TFF (823/1000) ...
# Error fetching MXP -> TFF: [400]
#
# Fetching MXP -> KTM (824/1000) ...
# Fetching MXP -> YHY (825/1000) ...
# Fetching MXP -> MOF (826/1000) ...
# Error fetching MXP -> MOF: [400]
#
# Fetching MXP -> ACI (827/1000) ...
# Fetching MXP -> UMB (828/1000) ...
# Error fetching MXP -> UMB: [400]
#
# Fetching MXP -> CAC (829/1000) ...
# Fetching MXP -> ZRT (830/1000) ...
# Fetching MXP -> SKE (831/1000) ...
# Fetching MXP -> OAK (832/1000) ...
# Fetching MXP -> DEM (833/1000) ...
# Error fetching MXP -> DEM: [400]
#
# Fetching MXP -> MWH (834/1000) ...
# Fetching MXP -> MMY (835/1000) ...
# Fetching MXP -> CCT (836/1000) ...
# Error fetching MXP -> CCT: [400]
#
# Fetching MXP -> UCK (837/1000) ...
# Error fetching MXP -> UCK: [400]
#
# Fetching MXP -> ELQ (838/1000) ...
# Fetching MXP -> RUK (839/1000) ...
# Fetching MXP -> PSE (840/1000) ...
# Error fetching MXP -> PSE: [400]
#
# Fetching MXP -> LWT (841/1000) ...
# Error fetching MXP -> LWT: [400]
#
# Fetching MXP -> BJX (842/1000) ...
# Fetching MXP -> KRQ (843/1000) ...
# Fetching MXP -> SFZ (844/1000) ...
# Error fetching MXP -> SFZ: [400]
#
# Fetching MXP -> PLU (845/1000) ...
# Fetching MXP -> VCT (846/1000) ...
# Fetching MXP -> AHE (847/1000) ...
# Error fetching MXP -> AHE: [400]
#
# Fetching MXP -> DWB (848/1000) ...
# Error fetching MXP -> DWB: [400]
#
# Fetching MXP -> AVX (849/1000) ...
# Error fetching MXP -> AVX: [400]
#
# Fetching MXP -> EAP (850/1000) ...
# Autosaved 850 airports to airports_with_prices.csv
# Fetching MXP -> JAX (851/1000) ...
# Fetching MXP -> CRI (852/1000) ...
# Fetching MXP -> KOS (853/1000) ...
# Error fetching MXP -> KOS: [400]
#
# Fetching MXP -> MSI (854/1000) ...
# Fetching MXP -> LPS (855/1000) ...
# Fetching MXP -> YZT (856/1000) ...
# Fetching MXP -> XAC (857/1000) ...
# Fetching MXP -> KGV (858/1000) ...
# Error fetching MXP -> KGV: [400]
#
# Fetching MXP -> FUK (859/1000) ...
# Fetching MXP -> YZH (860/1000) ...
# Error fetching MXP -> YZH: [400]
#
# Fetching MXP -> DRB (861/1000) ...
# Fetching MXP -> RMZ (862/1000) ...
# Error fetching MXP -> RMZ: [400]
#
# Fetching MXP -> DSA (863/1000) ...
# Error fetching MXP -> DSA: [400]
#
# Fetching MXP -> ZMU (864/1000) ...
# Fetching MXP -> OAR (865/1000) ...
# Fetching MXP -> YST (866/1000) ...
# Error fetching MXP -> YST: [400]
#
# Fetching MXP -> RMO (867/1000) ...
# Fetching MXP -> KGD (868/1000) ...
# Error fetching MXP -> KGD: [400]
#
# Fetching MXP -> HQM (869/1000) ...
# Fetching MXP -> TEN (870/1000) ...
# Error fetching MXP -> TEN: [400]
#
# Fetching MXP -> SVL (871/1000) ...
# Fetching MXP -> GNB (872/1000) ...
# Fetching MXP -> EDF (873/1000) ...
# Error fetching MXP -> EDF: [400]
#
# Fetching MXP -> LCK (874/1000) ...
# Error fetching MXP -> LCK: [400]
#
# Fetching MXP -> ZFR (875/1000) ...
# Error fetching MXP -> ZFR: [400]
#
# Fetching MXP -> IXZ (876/1000) ...
# Fetching MXP -> FLF (877/1000) ...
# Error fetching MXP -> FLF: [400]
#
# Fetching MXP -> TUW (878/1000) ...
# Error fetching MXP -> TUW: [400]
#
# Fetching MXP -> YOD (879/1000) ...
# Fetching MXP -> LBT (880/1000) ...
# Fetching MXP -> USN (881/1000) ...
# Fetching MXP -> WTL (882/1000) ...
# Fetching MXP -> TEB (883/1000) ...
# Fetching MXP -> KSY (884/1000) ...
# Fetching MXP -> LMY (885/1000) ...
# Fetching MXP -> BXD (886/1000) ...
# Fetching MXP -> SEU (887/1000) ...
# Error fetching MXP -> SEU: [400]
#
# Fetching MXP -> MAX (888/1000) ...
# Fetching MXP -> YPQ (889/1000) ...
# Fetching MXP -> MWK (890/1000) ...
# Fetching MXP -> NOC (891/1000) ...
# Fetching MXP -> PTY (892/1000) ...
# Fetching MXP -> ACX (893/1000) ...
# Error fetching MXP -> ACX: [400]
#
# Fetching MXP -> KWY (894/1000) ...
# Error fetching MXP -> KWY: [400]
#
# Fetching MXP -> PBF (895/1000) ...
# Error fetching MXP -> PBF: [400]
#
# Fetching MXP -> DIU (896/1000) ...
# Fetching MXP -> CVU (897/1000) ...
# Error fetching MXP -> CVU: [400]
#
# Fetching MXP -> YOL (898/1000) ...
# Fetching MXP -> IGT (899/1000) ...
# Error fetching MXP -> IGT: [400]
#
# Fetching MXP -> BMM (900/1000) ...
# Autosaved 900 airports to airports_with_prices.csv
# Fetching MXP -> KAW (901/1000) ...
# Fetching MXP -> GOV (902/1000) ...
# Error fetching MXP -> GOV: [400]
#
# Fetching MXP -> ELY (903/1000) ...
# Fetching MXP -> MVT (904/1000) ...
# Error fetching MXP -> MVT: [400]
#
# Fetching MXP -> SSH (905/1000) ...
# Fetching MXP -> RGI (906/1000) ...
# Error fetching MXP -> RGI: [400]
#
# Fetching MXP -> MAE (907/1000) ...
# Error fetching MXP -> MAE: [400]
#
# Fetching MXP -> VEO (908/1000) ...
# Error fetching MXP -> VEO: [400]
#
# Fetching MXP -> YSB (909/1000) ...
# Fetching MXP -> PKW (910/1000) ...
# Fetching MXP -> ZSJ (911/1000) ...
# Fetching MXP -> CDJ (912/1000) ...
# Error fetching MXP -> CDJ: [400]
#
# Fetching MXP -> TSH (913/1000) ...
# Fetching MXP -> ZSN (914/1000) ...
# Error fetching MXP -> ZSN: [400]
#
# Fetching MXP -> ULB (915/1000) ...
# Fetching MXP -> DEN (916/1000) ...
# Fetching MXP -> WBW (917/1000) ...
# Fetching MXP -> RIC (918/1000) ...
# Fetching MXP -> SLM (919/1000) ...
# Error fetching MXP -> SLM: [400]
#
# Fetching MXP -> NIO (920/1000) ...
# Error fetching MXP -> NIO: [400]
#
# Fetching MXP -> ETZ (921/1000) ...
# Error fetching MXP -> ETZ: [400]
#
# Fetching MXP -> BDE (922/1000) ...
# Error fetching MXP -> BDE: [400]
#
# Fetching MXP -> CJM (923/1000) ...
# Fetching MXP -> MWX (924/1000) ...
# Fetching MXP -> LLK (925/1000) ...
# Fetching MXP -> LKO (926/1000) ...
# Fetching MXP -> MBL (927/1000) ...
# Error fetching MXP -> MBL: [400]
#
# Fetching MXP -> MCN (928/1000) ...
# Error fetching MXP -> MCN: [400]
#
# Fetching MXP -> LSH (929/1000) ...
# Error fetching MXP -> LSH: [400]
#
# Fetching MXP -> MVD (930/1000) ...
# Fetching MXP -> DCF (931/1000) ...
# Error fetching MXP -> DCF: [400]
#
# Fetching MXP -> XSB (932/1000) ...
# Error fetching MXP -> XSB: [400]
#
# Fetching MXP -> MPW (933/1000) ...
# Fetching MXP -> VPE (934/1000) ...
# Error fetching MXP -> VPE: [400]
#
# Fetching MXP -> SZD (935/1000) ...
# Error fetching MXP -> SZD: [400]
#
# Fetching MXP -> HKT (936/1000) ...
# Fetching MXP -> ABD (937/1000) ...
# Error fetching MXP -> ABD: [400]
#
# Fetching MXP -> SRL (938/1000) ...
# Error fetching MXP -> SRL: [400]
#
# Fetching MXP -> SCY (939/1000) ...
# Error fetching MXP -> SCY: [400]
#
# Fetching MXP -> YOG (940/1000) ...
# Error fetching MXP -> YOG: [400]
#
# Fetching MXP -> PJA (941/1000) ...
# Error fetching MXP -> PJA: [400]
#
# Fetching MXP -> DUB (942/1000) ...
# Fetching MXP -> DRO (943/1000) ...
# Fetching MXP -> BMK (944/1000) ...
# Fetching MXP -> VQS (945/1000) ...
# Fetching MXP -> TEQ (946/1000) ...
# Fetching MXP -> LZO (947/1000) ...
# Fetching MXP -> YRS (948/1000) ...
# Fetching MXP -> CRK (949/1000) ...
# Fetching MXP -> JSH (950/1000) ...

# %%
# !pip install amadeus

import datetime
from amadeus import Client, ResponseError

# -------------------------------
# CONFIG
# -------------------------------
API_KEY = "ligX17GEhAERS34XjfmMW6rpG1c5uHZu"       # Replace with your Amadeus GET API key
API_SECRET = "2jWVw0p9UA72Ykke" # Replace with your Amadeus secret
ORIGIN = "MXP"
DESTINATION = "JFK"
DEPARTURE_DATE = (datetime.date.today() + datetime.timedelta(days=30)).strftime("%Y-%m-%d")

# -------------------------------
# INIT CLIENT
# -------------------------------
amadeus = Client(client_id=API_KEY, client_secret=API_SECRET)

# -------------------------------
# PRICE BUCKET / COLOR FUNCTION
# -------------------------------
def assign_bucket_and_color(price):
    if price is None:
        return "No Data", "#CCCCCC"
    elif price < 100:
        return "<100", "#0000FF"        # Blue
    elif price < 200:
        return "100-200", "#00FF00"    # Green 1
    elif price < 400:
        return "200-400", "#008000"    # Green 2
    elif price < 800:
        return "400-800", "#FFFF00"    # Yellow
    elif price < 1000:
        return "800-1000", "#FFA500"   # Orange
    else:
        return ">1000", "#FF0000"      # Red

# -------------------------------
# FETCH CHEAPEST FLIGHT
# -------------------------------
def get_cheapest_flight(origin, destination, date):
    try:
        response = amadeus.shopping.flight_offers_search.get(
            originLocationCode=origin,
            destinationLocationCode=destination,
            departureDate=date,
            adults=1,
            max=5
        )
        data = response.data
        if not data:
            return None
        prices = [float(offer['price']['total']) for offer in data if 'price' in offer]
        return min(prices) if prices else None
    except ResponseError as e:
        print(f"Error fetching {origin} -> {destination}: {e}")
        return None

# -------------------------------
# RUN
# -------------------------------
price = get_cheapest_flight(ORIGIN, DESTINATION, DEPARTURE_DATE)
bucket, color = assign_bucket_and_color(price)

print(f"{ORIGIN} -> {DESTINATION}:")
print(f"Price: {price}")
print(f"Bucket: {bucket}")
print(f"Color: {color}")
# Out:
# Requirement already satisfied: amadeus in /usr/local/lib/python3.12/dist-packages (12.0.0)
# MXP -> JFK:
# Price: 278.28
# Bucket: 200-400
# Color: #008000
